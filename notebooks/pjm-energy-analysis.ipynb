# %%
#PJM Energy Analysis Project
'''
This notebook aims to explore an hourly energy consumption dataset to discover trends in consumption across regions, seasons, and dates.
'''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from zipfile import ZipFile
#!pip install pyarrow fastparquet
import os

# %%
zipfile_path = "../data/PJMHourlyEnergyConsumption.zip"
extract_path = '../data/pjm_extract'

os.makedirs(extract_path, exist_ok=True)

with ZipFile(zipfile_path, 'r') as f:
    print(f.namelist()) #see/list all files inside
    f.extractall(extract_path)

os.listdir(extract_path)
# Out:
# ['AEP_hourly.csv', 'COMED_hourly.csv', 'DAYTON_hourly.csv', 'DEOK_hourly.csv', 'DOM_hourly.csv', 'DUQ_hourly.csv', 'EKPC_hourly.csv', 'FE_hourly.csv', 'NI_hourly.csv', 'PJME_hourly.csv', 'PJMW_hourly.csv', 'PJM_Load_hourly.csv', 'est_hourly.paruqet', 'pjm_hourly_est.csv']
# ['COMED_hourly.csv',
#  'est_hourly.paruqet',
#  'EKPC_hourly.csv',
#  'pjm_hourly_est.csv',
#  'NI_hourly.csv',
#  'PJMW_hourly.csv',
#  'DUQ_hourly.csv',
#  'DEOK_hourly.csv',
#  'PJM_Load_hourly.csv',
#  'DOM_hourly.csv',
#  'DAYTON_hourly.csv',
#  'FE_hourly.csv',
#  'PJME_hourly.csv',
#  'AEP_hourly.csv']
